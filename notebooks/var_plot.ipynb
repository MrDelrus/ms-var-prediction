# %% [markdown]
# # VaR vs Returns — comparison plot\n\nHardcode ticker, period, and which experiment CSVs to overlay. Run all cells."

# %%
# ── CONFIG ────────────────────────────────────────────────────────────────────
TICKER = "SPY"

# Add / remove entries to overlay more models. Keys become legend labels.
# Paths are relative to the repo root (outputs/var_series/<experiment>/<ticker>.csv).
SERIES = {
    "MSM 3-state": f"../outputs/var_series/msm_3state/{TICKER}.csv",
    "GMM 3-comp":  f"../outputs/var_series/gmm_3comp/{TICKER}.csv",
}

SAVE_PATH = None   # e.g. "../outputs/plots/SPY_nb.png"  — or None to just display
# ──────────────────────────────────────────────────────────────────────────────

# %%
import sys; sys.path.insert(0, "../src")
from ms_var_prediction.plotting import plot_var
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams["figure.dpi"] = 130

fig = plot_var(TICKER, SERIES, save_path=SAVE_PATH)
plt.show()
